# %% [markdown]
# # 10. DataFrame 활용

# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus']=False

# %%
labels = ['kronii', 'botan', 'anya']
values = [168, 166, 147]

plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
df = pd.read_excel('../Pandas/score.xlsx')
df
# Out:
#   지원번호    name club  height  Language  English  Math  science  Society
# 0   1번  kronii   EN     168        10       85    10       20       75  \
# 1   2번   botan   JP     166        30       35    65       95       35
# 2   3번    anya   ID     147        60       50    45       45       20
# 3   4번     mio   JP     160        90       30    35       90       90
# 4   5번  roboco   JP     154        80       15    75       55       45
# 5   6번  Marine   JP     150        65       80    55       75       95
# 6   7번   Baelz   EN     149        69       69    69       69      100
# 7   8번   okayu   JP     152        35       10    95       85       55
#
#            SW
# 0      Python
# 1        Java
# 2  Javascript
# 3         NaN
# 4         NaN
# 5           C
# 6      PYTHON
# 7          C#

# %%
plt.plot(df['지원번호'],df['height'])

# %%
plt.plot(df['지원번호'], df['English'])
plt.plot(df['지원번호'], df['Math'])

# %%
plt.plot(df['지원번호'], df['English'])
plt.plot(df['지원번호'], df['Math'])

plt.grid()

# %%
plt.plot(df['지원번호'], df['English'])
plt.plot(df['지원번호'], df['Math'])

plt.grid(axis='y')

# %%
plt.plot(df['지원번호'], df['English'])
plt.plot(df['지원번호'], df['Math'])

plt.grid(axis='y', color='purple', alpha=0.5, linestyle='--')

# %%
plt.plot(df['지원번호'], df['English'])
plt.plot(df['지원번호'], df['Math'])

plt.grid(axis='y', color='purple', alpha=0.5, linestyle='--', linewidth=2)
